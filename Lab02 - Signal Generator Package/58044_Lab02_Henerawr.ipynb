# %% [markdown]
# <a href="https://colab.research.google.com/github/Gonzales-James/DSP/blob/main/Lab02%20-%20Signal%20Generator%20Package/58044_Lab02_Henerawr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import siggenpy as sig

# %% [markdown]
# ### Impulse Signal

# %%
signal = "impulse"
sig.discrete_time.generate_signal(signal, -5, 5)

# %% [markdown]
# ### Unit Step

# %%
signal = "unit-step"
sig.discrete_time.generate_signal(signal, -5, 5)

# %% [markdown]
# ### Ramp Signal

# %%
signal = "ramp"
sig.discrete_time.generate_signal(signal, -5, 5)

# %% [markdown]
# ### Exponential Decay

# %%
signal = "decay"
sig.discrete_time.generate_signal(signal, -10, 10, 0.5)

# %% [markdown]
# ### Exponential Growth Signals

# %%
signal = "growth"
sig.discrete_time.generate_signal(signal, -10, 10, 2)

# %% [markdown]
# ### Leaky ReLU Signal

# %%
signal = "leaky"
sig.discrete_time.generate_signal(signal, -5, 5, 0.1)

# %% [markdown]
# ### ELU Signal

# %%
signal = "elu"
sig.discrete_time.generate_signal(signal, -5, 5, -0.5)

# %% [markdown]
# ### Sigmoid Signal

# %%
signal = "sigmoid"
sig.discrete_time.generate_signal(signal, -5, 5)
